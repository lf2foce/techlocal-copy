# %%
system_prompt = """ 

#PHẦN 1: TƯ DUY  Trước hết phải nói thẳng, cái thời mà tạo Page trắng, rồi dùng Tools bắn hàng trăm video lên rồi chờ ăn đề xuất, đã qua lâu rồi. Xây Page VN kiểu đó đã khó, chứ đừng nói đến Page US. Xác suất ăn 1 trên 100 thì vẫn có thể có, nhưng mà tỉ lệ đó quá thấp, không đáng để làm và cũng không phải cách tối ưu để làm.  Trước đây, mọi người thường truyền tai nhau là để có Page US, thì phải có một con VIA US, cho con VIA này sử dụng Proxy US rồi tạo Page. Cách làm này không sai, nhưng căn bản là cái Page US tạo ra rồi nó vẫn flop, có đăng bao nhiêu video đi chăng nữa vẫn sẽ là 0 View.  Vậy phải làm thế nào?  Cách làm của tôi mấy năm này là:  •        Không quan tâm VIA VN hay VIA US tạo Page, chỉ cần Page đó đem đi chạy quảng cáo tăng like US -> 100% nó sẽ reach tới tệp US  •        Mỗi Page chỉ cần chạy 500 – 1000 Like là được không cần nhiều, tất nhiên càng nhiều thì càng tốt.  Nói tóm lại, để có 1 Page US reach tới tệp US, chỉ cần chạy quảng cáo tăng Like US cho nó. Tùy theo niche mà giá quảng cáo/like sẽ khác nhau, giao động từ 100-500đ (cao thủ thì có thể chạy <100đ).  Khi chạy tăng Like kiểu này và thả không target gì, gần như toàn bộ người Like page sẽ là tệp người già. Cũng dễ hiểu thôi, người già, những người lớn tuổi, không rành công nghệ, không tiếp xúc nhiều với cái mới, sẽ “dễ dàng” thả Like hơn là những người trẻ tuổi.  Một Page toàn người già thì làm được gì? Ưu điểm lớn nhất – Là bạn đăng cái gì cũng dễ ăn đề xuất hơn bình thường.  Bạn đăng ảnh -> đề xuất Bạn đăng reels -> đề xuất  Khi đã ăn đề xuất, hướng kiếm tiền khả thi nhất là:  •        Bỏ link kéo về Website để ăn tiền từ các Adnetwork (của tôi là Adsense)  •        Bỏ link thả về ăn tiền Aff, POD, Drop  •        Chạy quảng cáo hiệu quả hơn hẳn (Vì đúng tệp)  Bây giờ nói về niche, một người già ở Mỹ, bạn sẽ thích gì? Họ sẽ thích tương tác với những thứ mang tính hoài niệm. Hiện tượng được gọi là hiệu ứng nostalgia, là một xu hướng tâm lý phổ biến và có cơ sở khoa học. Nostalgia không chỉ đơn thuần là sự nhớ nhung quá khứ, mà còn là một cơ chế tâm lý giúp con người, đặc biệt là người lớn tuổi, tìm lại cảm giác an ủi, ý nghĩa và kết nối với bản thân cũng như xã hội.  Những thứ hoài niệm ở đây là gì, nó có thể là: Xe cổ, nhạc xưa, phim xưa, gameshow xưa, những trò chơi tuổi thơ, những hình ảnh trắng đen…  Như Page dưới của tôi, tôi đăng Reel dưới dạng Video top list:  •        Top 10 bài hát hay nhất thập niên 70  •        Top 5 ca sĩ quyến rũ nhất những năm 1950  •        Top 10 bài hát để đời của Bon Jovi  Về hình ảnh:  •        Đăng hình ảnh quyển sách học chữ Dick and Jean (tương tự tiếng việt lớp 1 của VN)  •        Hình ảnh trạm xăng những năm 1960  •        Mấy câu quote về tuổi thơ  Như vậy áp dụng đúng công thức người già + niche hoài niệm, bạn sẽ có 1 page đăng cái gì cũng tương tác điên đảo.  Tệp đã đúng, chỉ cần lựa sản phẩm phù hợp để kiếm tiền:  •        Ảnh dưới là tôi đang bán áo POD, bán Mug POD.  •        Ảnh dưới nữa là tôi kéo traffic về site để ăn tiền adsense  PHẦN 2: BẮT TAY LÀM  1. Tạo Page: Không cần phức tạp VIA US hay Proxy, cứ dùng tài khoản thường tạo Page bình thường. Đặt tên Page ngắn gọn, dễ nhớ, liên quan đến Niche hoài niệm (ví dụ: “70s Memories”, “Retro Vibes”).  2. Chạy quảng cáo tăng Like: Vào Ads Manager, tạo chiến dịch “Page Likes”. Target: Chọn quốc gia US, độ tuổi 18-65+ (Ko cần Target gì) Ngân sách: 100-200k/ngày, chạy 3-5 ngày đạt 500-1000 Like thì dừng.  3. Chuẩn bị nội dung:  •        Reels: Tìm video ngắn (15-60s) trên YouTube hoặc TikTok về chủ đề hoài niệm (nhạc cũ, phim xưa, top list), edit lại nhẹ (thêm chữ, hiệu ứng) để tránh bản quyền. Như tôi cứ dùng Tools lật ngược, tăng speed 1.1, cắt 1s đầu và 1s cuối, 100% an toàn  •        Ảnh: Sưu tầm ảnh từ Google (xe cổ, đồ vật xưa, ảnh trắng đen), thêm caption kiểu quote như “Do you miss this?” hoặc “Who remembers these days?”…  4. Đăng bài đều đặn: Ngày đầu sau khi có Like, đăng 1-2 bài Từ ngày thứ 3, duy trì 1 Reel + 1 ảnh/ngày. Quan sát bài nào reach cao thì đẩy mạnh kiểu nội dung đó.  5. Kiếm tiền: Như đã nói ở trên  Nói chung tệp người già thích tương tác và tương đối trung thành, nếu kiên nhẫn làm nội dung chất lượng phục vụ được tệp này, ae có thể build lâu dài mà ko sợ lỗ. Chúc anh em thành công và kiếm được kha khá từ thị trường US!  Nếu thấy hay đừng tiếc gì 1 Like & Share nhé ae!  #Bài viết được chia sẻ từ Sống Cùng Affiliate | Permate.com. 
#  Học tập tư duy và cách làm từ bài viết này để ứng dụng, triển khai cho một hệ thống kênh mới trên social 
- về chủ đề: {desc} 
# - với tập khách {target_customer} 
# - insight lớn nhất của tệp này là: {insight}
"""

# về chủ đề: nam tính mới 
# - với tập khách hàng nam giới trưởng thành 25-45 
# - insight lớn nhất của tệp này là: Nam giới k nên là người phải chịu đựng mọi thứ 1 mình (trong gia đình) để bùng nổ cùng chiến dịch nam tính mới toàn cầu của oniiz

# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
from pydantic import BaseModel
import asyncio
from typing import Dict, Any, List
import os, json

load_dotenv()

class Theme(BaseModel):
    title: str
    story: str

class ThemeGenerate(BaseModel):
    themes: List[Theme]
    mindset: str   
    plan: str

def generate_theme_title_and_story(campaign_title: str, insight: str, description: str, target_customer:str) -> List[tuple[str, str]]:
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
    
    # Generate response using Gemini API (synchronous version)
    response = client.models.generate_content(
        model='gemini-2.0-flash',
        contents=f"Lập kế hoạch triển khai hệ thống kênh social mới để bùng nổ cùng chiến dịch nam tính mới toàn cầu của oniiz.", # Tạo 5 thương hiệu cho pages với các thông tin {insight} {target_customer}. Mỗi thương hiệu phải có title và story khác nhau.
        config=types.GenerateContentConfig(
            response_mime_type='application/json',
            response_schema=ThemeGenerate,
            system_instruction=types.Part.from_text(text=system_prompt.format(desc=description, target_customer=target_customer, insight=insight)),
        ),
    )
    
    # Extract the response
    print("Generated 5 themes based on user prompt.")
    content = json.loads(response.text)
    
    # Validate and parse the response using Pydantic
    themes_data = ThemeGenerate(**content)
    
    # Convert list of themes to list of tuples using dot notation for Pydantic model attributes
    return themes_data.mindset, themes_data.plan
    return [(theme.title, theme.story) for theme in themes_data.themes]

# %%
a = generate_theme_title_and_story(campaign_title='xyz', insight='Nam giới k nên là người phải chịu đựng mọi thứ 1 mình (trong gia đình) ', 
    description='nam tính mới', target_customer='nam giới trưởng thành 25-45 ')
# Out:
# Generated 5 themes based on user prompt.

# %%
c,d = a

# %%
print(d)
# Out:
# 1. **Nghiên cứu từ khóa và hashtag:** Tìm kiếm các từ khóa và hashtag liên quan đến 'nam tính mới', 'sức khỏe tinh thần nam giới', 'vai trò người đàn ông hiện đại', v.v. để tối ưu hóa nội dung và tăng khả năng tiếp cận. 2. **Xây dựng hệ thống kênh đa nền tảng:** Tập trung vào các nền tảng mà đối tượng mục tiêu (nam giới 25-45) thường xuyên sử dụng, ví dụ: Facebook, Instagram, YouTube, TikTok, LinkedIn. Tận dụng các định dạng nội dung khác nhau phù hợp với từng nền tảng: video ngắn, bài viết blog, podcast, infographic, v.v. 3. **Tạo nội dung chất lượng cao, nhất quán:**  - **Video:** Phỏng vấn những người đàn ông có câu chuyện truyền cảm hứng, chia sẻ lời khuyên từ chuyên gia về sức khỏe tinh thần và các mối quan hệ, tạo các video hoạt hình ngắn giải thích các khái niệm về nam tính mới.  - **Bài viết blog:** Chia sẻ các bài viết sâu sắc về các chủ đề liên quan đến nam tính mới, cung cấp các công cụ và tài nguyên hữu ích để giúp đàn ông cải thiện cuộc sống.  - **Podcast:** Tổ chức các 
# ...

# %%
from typing import List
from pydantic import BaseModel
import os
import json
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

# --- STRUCTS ---
class BrandTheme(BaseModel):
    name: str
    core_promise: str
    mission_line: str
    emotional_manifesto: str
    purpose_tagline: str
    # story: str

class StrategyInputResponse(BaseModel):
    themes: List[BrandTheme]
    mindset: str
    plan: List[str]

import textwrap
def generate_themes_mindset_plan(campaign_title: str, insight: str, description: str, target_customer: str):
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

    prompt_instruction = textwrap.dedent(f"""
    #PHẦN 1: TƯ DUY  Trước hết phải nói thẳng, cái thời mà tạo Page trắng, rồi dùng Tools bắn hàng trăm video lên rồi chờ ăn đề xuất, đã qua lâu rồi. Xây Page VN kiểu đó đã khó, chứ đừng nói đến Page US. Xác suất ăn 1 trên 100 thì vẫn có thể có, nhưng mà tỉ lệ đó quá thấp, không đáng để làm và cũng không phải cách tối ưu để làm.  Trước đây, mọi người thường truyền tai nhau là để có Page US, thì phải có một con VIA US, cho con VIA này sử dụng Proxy US rồi tạo Page. Cách làm này không sai, nhưng căn bản là cái Page US tạo ra rồi nó vẫn flop, có đăng bao nhiêu video đi chăng nữa vẫn sẽ là 0 View.  Vậy phải làm thế nào?  Cách làm của tôi mấy năm này là:  •        Không quan tâm VIA VN hay VIA US tạo Page, chỉ cần Page đó đem đi chạy quảng cáo tăng like US -> 100% nó sẽ reach tới tệp US  •        Mỗi Page chỉ cần chạy 500 – 1000 Like là được không cần nhiều, tất nhiên càng nhiều thì càng tốt.  Nói tóm lại, để có 1 Page US reach tới tệp US, chỉ cần chạy quảng cáo tăng Like US cho nó. Tùy theo niche mà giá quảng cáo/like sẽ khác nhau, giao động từ 100-500đ (cao thủ thì có thể chạy <100đ).  Khi chạy tăng Like kiểu này và thả không target gì, gần như toàn bộ người Like page sẽ là tệp người già. Cũng dễ hiểu thôi, người già, những người lớn tuổi, không rành công nghệ, không tiếp xúc nhiều với cái mới, sẽ “dễ dàng” thả Like hơn là những người trẻ tuổi.  Một Page toàn người già thì làm được gì? Ưu điểm lớn nhất – Là bạn đăng cái gì cũng dễ ăn đề xuất hơn bình thường.  Bạn đăng ảnh -> đề xuất Bạn đăng reels -> đề xuất  Khi đã ăn đề xuất, hướng kiếm tiền khả thi nhất là:  •        Bỏ link kéo về Website để ăn tiền từ các Adnetwork (của tôi là Adsense)  •        Bỏ link thả về ăn tiền Aff, POD, Drop  •        Chạy quảng cáo hiệu quả hơn hẳn (Vì đúng tệp)  Bây giờ nói về niche, một người già ở Mỹ, bạn sẽ thích gì? Họ sẽ thích tương tác với những thứ mang tính hoài niệm. Hiện tượng được gọi là hiệu ứng nostalgia, là một xu hướng tâm lý phổ biến và có cơ sở khoa học. Nostalgia không chỉ đơn thuần là sự nhớ nhung quá khứ, mà còn là một cơ chế tâm lý giúp con người, đặc biệt là người lớn tuổi, tìm lại cảm giác an ủi, ý nghĩa và kết nối với bản thân cũng như xã hội.  Những thứ hoài niệm ở đây là gì, nó có thể là: Xe cổ, nhạc xưa, phim xưa, gameshow xưa, những trò chơi tuổi thơ, những hình ảnh trắng đen…  Như Page dưới của tôi, tôi đăng Reel dưới dạng Video top list:  •        Top 10 bài hát hay nhất thập niên 70  •        Top 5 ca sĩ quyến rũ nhất những năm 1950  •        Top 10 bài hát để đời của Bon Jovi  Về hình ảnh:  •        Đăng hình ảnh quyển sách học chữ Dick and Jean (tương tự tiếng việt lớp 1 của VN)  •        Hình ảnh trạm xăng những năm 1960  •        Mấy câu quote về tuổi thơ  Như vậy áp dụng đúng công thức người già + niche hoài niệm, bạn sẽ có 1 page đăng cái gì cũng tương tác điên đảo.  Tệp đã đúng, chỉ cần lựa sản phẩm phù hợp để kiếm tiền:  •        Ảnh dưới là tôi đang bán áo POD, bán Mug POD.  •        Ảnh dưới nữa là tôi kéo traffic về site để ăn tiền adsense  PHẦN 2: BẮT TAY LÀM  1. Tạo Page: Không cần phức tạp VIA US hay Proxy, cứ dùng tài khoản thường tạo Page bình thường. Đặt tên Page ngắn gọn, dễ nhớ, liên quan đến Niche hoài niệm (ví dụ: “70s Memories”, “Retro Vibes”).  2. Chạy quảng cáo tăng Like: Vào Ads Manager, tạo chiến dịch “Page Likes”. Target: Chọn quốc gia US, độ tuổi 18-65+ (Ko cần Target gì) Ngân sách: 100-200k/ngày, chạy 3-5 ngày đạt 500-1000 Like thì dừng.  3. Chuẩn bị nội dung:  •        Reels: Tìm video ngắn (15-60s) trên YouTube hoặc TikTok về chủ đề hoài niệm (nhạc cũ, phim xưa, top list), edit lại nhẹ (thêm chữ, hiệu ứng) để tránh bản quyền. Như tôi cứ dùng Tools lật ngược, tăng speed 1.1, cắt 1s đầu và 1s cuối, 100% an toàn  •        Ảnh: Sưu tầm ảnh từ Google (xe cổ, đồ vật xưa, ảnh trắng đen), thêm caption kiểu quote như “Do you miss this?” hoặc “Who remembers these days?”…  4. Đăng bài đều đặn: Ngày đầu sau khi có Like, đăng 1-2 bài Từ ngày thứ 3, duy trì 1 Reel + 1 ảnh/ngày. Quan sát bài nào reach cao thì đẩy mạnh kiểu nội dung đó.  5. Kiếm tiền: Như đã nói ở trên  Nói chung tệp người già thích tương tác và tương đối trung thành, nếu kiên nhẫn làm nội dung chất lượng phục vụ được tệp này, ae có thể build lâu dài mà ko sợ lỗ. Chúc anh em thành công và kiếm được kha khá từ thị trường US!  Nếu thấy hay đừng tiếc gì 1 Like & Share nhé ae!  #Bài viết được chia sẻ từ Sống Cùng Affiliate | Permate.com. #  Học tập tư duy và cách làm từ bài viết này để ứng dụng, triển khai cho một hệ thống kênh mới trên social về chủ đề: 
    
    - Tên chiến dịch: {campaign_title}
    - 🎯 Insight trọng tâm: {insight}  
    - 👥 Đối tượng mục tiêu: {target_customer}  
    - 📄 Bối cảnh & mục tiêu chiến dịch: {description}
    
    🎨 Nhiệm vụ:
    Trả về một JSON object gồm 3 phần:
    themes: Gợi ý 5 tên page thương hiệu riêng biệt. Mỗi mục gồm:
        name: Tên thương hiệu, truyền cảm hứng và dễ ghi nhớ
        core_promise: Lời hứa thương hiệu – linh hồn của chiến dịch, cam kết cảm xúc
        mission_line: Mục tiêu hành động – súc tích, rõ định hướng
        emotional_manifesto: Tuyên ngôn cảm xúc – thể hiện triết lý nhân văn
        purpose_tagline: Tagline cô đọng – dùng trên banner, video, social bio
    -mindset: mô tả tư duy cảm xúc của chiến dịch, từ 200–300 từ, là danh sách các gạch đầu dòng ngắn, thể hiện tư duy chiến dịch và cách tiếp cận nội dung mới.
    -plan: Gợi ý 30 caption hoặc tiêu đề cho các nội dung đăng liên tục trong 30 ngày đầu xây dựng kênh. Mỗi phần là 1 string. Dạng gợi mở, cảm xúc, khơi gợi sự đồng cảm, không bán hàng.
    
    --------
    Ví dụ đầu ra hợp lệ:
    {{
      "themes": [
         {{
      "name": "Nam tính mới",
      "core_promise": "Nơi tiếng nói đàn ông được vang lên – không bị đánh giá, không bị gạt đi.",
      "mission_line": "Phá bỏ im lặng, giải phóng cảm xúc – trao quyền cho đàn ông dám chia sẻ.",
      "emotional_manifesto": "Đằng sau sự im lặng của đàn ông là một đại dương cảm xúc chưa từng được gọi tên. Chúng tôi đến để lắng nghe.",
      "purpose_tagline": "Im lặng không còn là lựa chọn."
        }},
        {{
        "name": "Nội tâm đàn ông",
        "core_promise": "Giúp người đàn ông thấu hiểu nội tâm, chữa lành và phát triển từ bên trong.",
        "mission_line": "Tái định nghĩa nam tính bằng chiều sâu cảm xúc và sự tự nhận thức.",
        "emotional_manifesto": "Bên trong mỗi người đàn ông là một hành trình chưa kể – chúng tôi ở đây để cùng đi hết chặng đường đó.",
        "purpose_tagline": "Nam tính là hiểu chính mình."
        }},
        ...
      ],
      "mindset": "- Tư duy cũ không còn hiệu quả: spam content, chờ may mắn\\n- Định hướng mới: đánh trúng tệp, đúng cảm xúc, đúng thời điểm\\n- Không cần VIA US, chỉ cần chạy ads tăng like từ US là được\\n...",
      "plan": [
       "Bạn không cần phải mạnh mẽ mỗi ngày – đôi khi yếu đuối mới là sức mạnh",
        "Đàn ông cũng cần không gian để được lắng nghe",
        "Một ngày trong tâm trí người đàn ông trưởng thành",
        "Không ai hỏi bạn mệt chưa – chỉ hỏi bạn đã lo xong chưa",
        "Là đàn ông – cũng có quyền được tổn thương",
        "Mạnh mẽ không có nghĩa là không đau",
        "Bạn có từng cảm thấy mình đang gồng quá lâu?",
        "Nam tính không phải là vai diễn, nó là sự thật bên trong bạn",
        "Ai là người bạn có thể chia sẻ mà không cần giải thích?",
        "Người cha, người con, người chồng – ba vai diễn một cuộc đời",
        "Khi đàn ông không nói ra – họ đang hét trong im lặng",
        "Bạn không cần phải ổn chỉ vì người khác mong bạn thế",
        ...
      ]
    }}
    """)

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=f"Chiến dịch: {campaign_title}",
        config=types.GenerateContentConfig(
            response_mime_type="application/json",
            response_schema=StrategyInputResponse,
            system_instruction=types.Part.from_text(text=prompt_instruction)
        ),
    )

    print("✔ Generated themes, mindset, and 30-day content plan")
    parsed = StrategyInputResponse(**json.loads(response.text))

    return parsed # response.text

# a = generate_themes_mindset_plan("Nam Tính Mới", "Đàn ông không nên chịu đựng một mình", 
#     "Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại", "Nam giới 25–45 tuổi ở thành thị")
a = generate_themes_mindset_plan("giày cá tính", "đôi giày ôm sát chân tạo cảm giác bước đi tự tin", 
    "Chiến dịch giúp quảng bá giày cá tính đến được một cách tự tin", "Nam giới 25–45 tuổi ở thành thị")
print(a)
# Out:
# ✔ Generated themes, mindset, and 30-day content plan
# ...

# %%
a.model_dump()
# Out:
# {'themes': [{'name': 'Bước Chân Kiêu Hãnh',
#    'core_promise': 'Nâng tầm phong thái, khẳng định bản lĩnh trên mỗi bước đi.',
#    'mission_line': 'Mang đến những đôi giày không chỉ là phụ kiện, mà còn là tuyên ngôn cá tính.',
#    'emotional_manifesto': 'Đôi giày cá tính không chỉ bảo vệ đôi chân, mà còn là người bạn đồng hành trên hành trình chinh phục thành công.',
#    'purpose_tagline': 'Giày cá tính, bước đi tự tin.'},
#   {'name': 'Dấu Ấn Riêng',
#    'core_promise': 'Thể hiện chất tôi, khẳng định dấu ấn cá nhân qua từng thiết kế giày độc đáo.',
#    'mission_line': 'Truyền cảm hứng sáng tạo, khuyến khích phái mạnh tự tin thể hiện bản thân.',
#    'emotional_manifesto': 'Mỗi đôi giày là một câu chuyện, mỗi bước đi là một lời khẳng định. Hãy để Dấu Ấn Riêng kể câu chuyện của bạn.',
#    'purpose_tagline': 'Cá tính từ bước chân.'},
#   {'name': 'UrbanStride',
#    'core_promise': 'Đồng hành cùng bạn trên mọi nẻo đường thành phố, mang đến sự thoải mái và phong cách.',
# ...

# %%
from typing import List, Literal, Optional
from pydantic import BaseModel
from datetime import date, timedelta
import random
import os
import json
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

# --- STRUCTS ---
class MindsetSection(BaseModel):
    title: str
    content: str
#1
class PageSetup(BaseModel):
    page_name: str
    intro_story: str

class ContentItem(BaseModel):
    day: int
    content_type: Literal["quote", "reel", "confession", "story", "photo"]
    title: str
    description_ref: str

class GeneratedContent(BaseModel):
    day: int
    content_type: str
    caption: str
    hashtags: Optional[str]
    idea: Optional[str]
    image_prompts: Optional[List[str]] = None
#1
class BrandTheme(BaseModel):
    name: str
    manifesto: str

#1
class StrategyInputResponse(BaseModel):
    themes: List[BrandTheme]
    mindset: str
    plan: str

#1
class StrategyBundle(BaseModel):
    insight: str
    target_customer: str
    tone_of_voice: str
    page_setup: PageSetup
    mindset: List[MindsetSection]
    content_plan: List[ContentItem]

# --- FUNCTION 1: Generate Mindset, Page, Plan using Gemini ---
def generate_strategy_bundle_gemini(campaign_title: str, insight: str, description: str, target_customer: str) -> StrategyBundle:
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

    system_prompt = f"""
    Bạn là chiến lược gia nội dung chuyên về xây dựng chiến dịch xã hội.

    Hãy tạo kế hoạch xây dựng hệ thống kênh social cho chiến dịch \"{campaign_title}\".
    Chiến dịch này hướng đến đối tượng: {target_customer}.
    Insight cốt lõi: {insight}.

    Hãy dựa trên phong cách làm nội dung giống như sau:
    - Không còn thời của spam tool, nội dung cần có chiến lược, insight đúng, cảm xúc thật.
    - Xây page có định vị rõ ràng, kết nối với nhu cầu cảm xúc.
    - Nội dung reels, ảnh, quote đều gợi cảm xúc sâu sắc.
    - Content có thể dùng để tăng tương tác, kéo traffic hoặc gắn link POD.

    Trả kết quả JSON gồm 3 phần:
    - mindset: tư duy cảm xúc của chiến dịch
    - plan: kế hoạch triển khai nội dung
    - themes: danh sách 5 page với name và manifesto (emotional brand statement)
    """

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=f"Chiến dịch: {campaign_title}",
        config=types.GenerateContentConfig(
            response_mime_type="application/json",
            response_schema=StrategyInputResponse,
            system_instruction=types.Part.from_text(text=system_prompt)
        ),
    )

    data = StrategyInputResponse(**json.loads(response.text))

    mindset_section = [MindsetSection(title="Tư duy chiến dịch", content=data.mindset)]
    themes = data.themes
    page_setup = PageSetup(page_name=themes[0].name, intro_story=themes[0].manifesto)

    #    "quote": "Trích dẫn truyền cảm hứng giúp nam giới nhìn nhận cảm xúc một cách tích cực.",
    #     "reel": "Reel ngắn gợi cảm xúc hoặc phản ánh một khoảnh khắc chân thật của đàn ông.",
    #     "confession": "Chia sẻ thật, ẩn danh về áp lực mà nam giới thường không dám nói ra.",
            # "photo": "Ảnh giàu cảm xúc với lời nhắn chạm tới tâm lý người xem."

    types_list = [ "story"] # "quote", "reel", "confession", , "photo"
    preset_descriptions = {
     
        "story": "Một câu chuyện đời thực hoặc hư cấu khơi gợi sự đồng cảm, độ dài ít nhất 300 từ.",
    }

    random.shuffle(types_list)
    repeated_types = (types_list * 6)[:30]

    content_plan = [
        ContentItem(
            day=i+1,
            content_type=ctype,
            title=f"Ngày {i+1} - Nội dung {ctype.title()}",
            description_ref=preset_descriptions[ctype]
        )
        for i, ctype in enumerate(repeated_types)
    ]

    return StrategyBundle(
        insight=insight,
        target_customer=target_customer,
        tone_of_voice="Đồng cảm, truyền cảm hứng, hiện đại nhưng không sướt mướt",
        page_setup=page_setup,
        mindset=mindset_section,
        content_plan=content_plan
    )

# --- FUNCTION 2: Generate Daily Content using Gemini ---
def generate_ai_content_gemini(item: ContentItem, strategy: StrategyBundle) -> GeneratedContent:
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

    mindset_text = "\n".join([f"{s.title}: {s.content}" for s in strategy.mindset])

    system_prompt = f"""
    Bạn là chuyên gia sáng tạo nội dung cho chiến dịch \"{strategy.page_setup.page_name}\" – một chiến dịch toàn cầu hướng đến nam giới hiện đại.

    Chiến dịch tập trung vào insight: \"{strategy.insight}\", dành cho {strategy.target_customer}.
    Tone-of-voice: {strategy.tone_of_voice}.

    Tuyên ngôn thương hiệu:
    {strategy.page_setup.intro_story}

    Tư duy chiến dịch:
    {mindset_text}

    Ghi nhớ:
    - caption có thể ngắn, mang tính hook.
    - nếu content_type là \"story\" thì viết bài dài ít nhất 300 từ như một bài blog.
    - nếu content_type là \"reel\" hoặc liên quan video thì tạo thêm một trường idea mô tả chi tiết để dùng sinh hình ảnh AI (image_prompt).

    Trả kết quả JSON:
    {{
      "caption": "...",
      "hashtags": "...",
      "idea": "..."
    }}
    """

    user_prompt = f"""
    - Ngày: {item.day}
    - Dạng: {item.content_type}
    - Chủ đề: {item.title}
    - Nội dung theo định hướng: {item.description_ref}
    """

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=user_prompt,
        config=types.GenerateContentConfig(
            response_mime_type="application/json",
            response_schema=GeneratedContent,
            system_instruction=types.Part.from_text(text=system_prompt)
        ),
    )

    raw = json.loads(response.text)

    if item.content_type in ["story", "reel"] and raw.get("idea"):
        base_prompt = raw["idea"]
        raw["image_prompts"] = [
            f"{base_prompt}, góc nhìn toàn cảnh",
            f"{base_prompt}, góc nhìn cận cảnh",
            f"{base_prompt}, biểu cảm gương mặt",
            f"{base_prompt}, hành động đang diễn ra"
        ]

    return GeneratedContent(**raw)

# --- DEMO: In 3 ngày đầu tiên và gợi ý image_prompt nếu cần ---
# if __name__ == "__main__":
#     strategy = generate_strategy_bundle_gemini(
#         campaign_title="Nam Tính Mới",
#         insight="Đàn ông không nên chịu đựng một mình",
#         description="Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại",
#         target_customer="Nam giới 25–45 tuổi ở thành thị"
#     )

#     for i in range(3):
#         content = generate_ai_content_gemini(strategy.content_plan[i], strategy)
#         print(f"\n📅 Ngày {content.day} - [{content.content_type.upper()}]")
#         print("📌 Caption:", content.caption)
#         print("🏷️ Hashtags:", content.hashtags)
#         print("🧠 Idea:", content.idea)

#         if content.image_prompts:
#             for j, prompt in enumerate(content.image_prompts, 1):
#                 print(f"🖼️ Image Prompt {j}: {prompt}")

# %%
strategy = generate_strategy_bundle_gemini(
        campaign_title="Nam Tính Mới",
        insight="Đàn ông không nên chịu đựng một mình",
        description="Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại",
        target_customer="Nam giới 25–45 tuổi ở thành thị"
    )
strategy.model_dump()
# Out:
# {'insight': 'Đàn ông không nên chịu đựng một mình',
#  'target_customer': 'Nam giới 25–45 tuổi ở thành thị',
#  'tone_of_voice': 'Đồng cảm, truyền cảm hứng, hiện đại nhưng không sướt mướt',
#  'page_setup': {'page_name': 'Góc Nam',
#   'intro_story': 'Nơi đàn ông chia sẻ, được lắng nghe, và tìm thấy sức mạnh từ sự đồng cảm.'},
#  'mindset': [{'title': 'Tư duy chiến dịch',
#    'content': 'Nam Tính Mới là sự cởi mở, sẻ chia, và chấp nhận những cảm xúc thật. Đó là sức mạnh đến từ sự đồng cảm và kết nối, không phải sự cô đơn và gồng gánh.'}],
#  'content_plan': [{'day': 1,
#    'content_type': 'story',
#    'title': 'Ngày 1 - Nội dung Story',
#    'description_ref': 'Một câu chuyện đời thực hoặc hư cấu khơi gợi sự đồng cảm, độ dài ít nhất 300 từ.'},
#   {'day': 2,
#    'content_type': 'story',
#    'title': 'Ngày 2 - Nội dung Story',
#    'description_ref': 'Một câu chuyện đời thực hoặc hư cấu khơi gợi sự đồng cảm, độ dài ít nhất 300 từ.'},
#   {'day': 3,
#    'content_type': 'story',
# ...

# %%
STRATEGY = generate_strategy_bundle_gemini(
        campaign_title="xx",
        insight="thích giày cá tính",
        description="Chiến dịch nâng cao nhận thức về sự tư do",
        target_customer="Nam giới 25–45 tuổi ở thành thị"
    )

# %%
STRATEGY.model_dump()
# Out:
# {'insight': 'thích giày cá tính',
#  'target_customer': 'Nam giới 25–45 tuổi ở thành thị',
#  'tone_of_voice': 'Đồng cảm, truyền cảm hứng, hiện đại nhưng không sướt mướt',
#  'page_setup': {'page_name': 'Sneaker Sanctuary',
#   'intro_story': 'Nơi tôn vinh những đôi giày, không chỉ là vật phẩm, mà là biểu tượng của phong cách và cá tính. Cảm nhận sự kết nối giữa đam mê và sự tự tin.'},
#  'mindset': [{'title': 'Tư duy chiến dịch',
#    'content': 'Xây dựng một cộng đồng những người đàn ông yêu thích giày dép như một biểu tượng của phong cách cá nhân và sự tự tin. Tạo ra nội dung chân thực, sâu sắc, chạm đến cảm xúc và khơi gợi sự đồng điệu trong đam mê.'}],
#  'content_plan': [{'day': 1,
#    'content_type': 'story',
#    'title': 'Ngày 1 - Nội dung Story',
#    'description_ref': 'Một câu chuyện đời thực hoặc hư cấu khơi gợi sự đồng cảm, độ dài ít nhất 300 từ.'},
#   {'day': 2,
#    'content_type': 'confession',
#    'title': 'Ngày 2 - Nội dung Confession',
# ...

# %%
x = generate_ai_content_gemini(STRATEGY.content_plan[7], STRATEGY)
print(x)
# Out:
# day=8 content_type='photo' caption='Đôi giày không chỉ để bước đi. Nó còn là cách bạn kể câu chuyện của chính mình. #SneakerSanctuary #PhongCachCaNhan' hashtags='#SneakerSanctuary #PhongCachCaNhan #GiayNam' idea=None

# %%
strategy = generate_strategy_bundle_gemini(
    campaign_title="Nam Tính Mới",
    insight="Đàn ông không nên chịu đựng một mình",
    description="Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại",
    target_customer="Nam giới 25–45 tuổi ở thành thị"
)

for i in range(3):
    content = generate_ai_content_gemini(strategy.content_plan[i], strategy)
    print("📌 Caption:", content.caption)
    print("🏷️ Hashtags:", content.hashtags)
    print("🧠 Idea:", content.idea)
# Out:
# 📌 Caption: Đừng ngại khi cảm thấy yếu đuối. Đó là dấu hiệu cho thấy bạn đủ mạnh mẽ để đối diện với chính mình.
# 🏷️ Hashtags: #TheBrotherhood #ManUp #CamXucThat
# 🧠 Idea: None
# 📌 Caption: Đôi khi, mạnh mẽ nhất là khi ta dám yếu đuối. #TheBrotherhood #KhongSaoKhiKhongOn
# 🏷️ Hashtags: #TheBrotherhood #KhongSaoKhiKhongOn #ManhoodRedefined
# 🧠 Idea: Một người đàn ông ngồi một mình trong quán cafe, vẻ mặt trầm tư. Anh ta nhìn vào điện thoại, do dự một lúc rồi nhắn tin cho một người bạn. Đoạn tin nhắn hiện lên: "Tao đang không ổn lắm, có thể gặp mày được không?". Người bạn trả lời ngay lập tức: "Đến ngay đây.". Cảnh kết: Hai người đàn ông ngồi đối diện, cùng nhau trò chuyện, một người lắng nghe, một người chia sẻ.
# 📌 Caption: Ngày thứ 3 của "The Brotherhood": Thật lòng mình đi anh em. Có những áp lực nào mà bạn luôn phải gồng mình chịu đựng?
# 🏷️ Hashtags: #TheBrotherhood #ManUp #RealTalk #MentalHealth #NamGioi
# 🧠 Idea: None

# %%
#worked v1
from typing import List, Literal, Optional
from pydantic import BaseModel
from datetime import date, timedelta
import random
import os
import json
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

# --- STRUCTS ---
class MindsetSection(BaseModel):
    title: str
    content: str

class PageSetup(BaseModel):
    page_name: str
    intro_story: str

class ContentItem(BaseModel):
    day: int
    content_type: Literal["quote", "reel", "confession", "story", "photo"]
    title: str
    description: str

class GeneratedContent(BaseModel):
    day: int
    content_type: str
    caption: str
    hashtags: Optional[str]
    idea: Optional[str]

class Theme(BaseModel):
    title: str
    story: str

class ThemeGenerate(BaseModel):
    themes: List[Theme]
    mindset: str
    plan: str

# --- FUNCTION 1: Generate Mindset, Page, Plan using Gemini ---
def generate_strategy_bundle_gemini(campaign_title: str, insight: str, description: str, target_customer: str):
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

    system_prompt = """
    Bạn là chiến lược gia nội dung chuyên về xây dựng chiến dịch xã hội.
    Hãy tạo kế hoạch cho một chiến dịch truyền thông mang tên \"{desc}\", tập trung vào insight \"{insight}\" và khách hàng mục tiêu \"{target_customer}\".

    Xuất kết quả dạng JSON với 3 phần:
    - mindset: tư duy định hướng chiến dịch
    - plan: kế hoạch triển khai
    - themes: danh sách 5 page có title + story
    """

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=f"Chiến dịch: {campaign_title}",
        config=types.GenerateContentConfig(
            response_mime_type="application/json",
            response_schema=ThemeGenerate,
            system_instruction=types.Part.from_text(text=system_prompt.format(
                desc=description,
                target_customer=target_customer,
                insight=insight,
            )),
        ),
    )

    print("Generated strategy bundle with mindset, plan, and themes.")
    content = json.loads(response.text)
    data = ThemeGenerate(**content)

    mindset_section = [MindsetSection(title="Tư duy chiến dịch", content=data.mindset)]
    plan_section = data.plan
    themes = data.themes
    page_setup = PageSetup(page_name=themes[0].title, intro_story=themes[0].story)

    types_list = ["quote", "reel", "confession", "story", "photo"]
    content_plan = []
    for i in range(1, 31):
        content_type = random.choice(types_list)
        title = f"Ngày {i} - Nội dung {content_type.title()}"
        description = f"{plan_section} - Dạng nội dung: {content_type}"
        content_plan.append(ContentItem(day=i, content_type=content_type, title=title, description=description))

    return {
        "mindset": mindset_section,
        "page_setup": page_setup,
        "content_plan": content_plan
    }

# --- FUNCTION 2: Generate Daily Content using Gemini ---
def generate_ai_content_gemini(item: ContentItem, mindset: List[MindsetSection]) -> GeneratedContent:
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

    mindset_text = "\n".join([f"{s.title}: {s.content}" for s in mindset])

    user_prompt = f"""
    Bạn là chuyên gia sáng tạo nội dung cho chiến dịch Nam Tính Mới. Dưới đây là tư duy chiến dịch:
    {mindset_text}

    Hãy tạo nội dung social media cho:
    - Ngày: {item.day}
    - Dạng: {item.content_type}
    - Chủ đề: {item.title}

    Xuất kết quả gồm:
    1. Caption cảm xúc
    2. Hashtags
    3. Gợi ý idea nếu là ảnh hoặc video
    """

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=user_prompt,
        config=types.GenerateContentConfig(response_mime_type="text/plain"),
    )

    return GeneratedContent(
        day=item.day,
        content_type=item.content_type,
        caption=response.text,
        hashtags="#NamTínhMới #KhôngMộtMình",
        idea=f"Idea for: {item.title}"
    )

# Example usage:
if __name__ == "__main__":
    STRATEGY = generate_strategy_bundle_gemini(
        campaign_title="Nam Tính Mới",
        insight="Đàn ông không nên chịu đựng một mình",
        description="Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại",
        target_customer="Nam giới 25–45 tuổi ở thành thị"
    )

    MINDSET = STRATEGY["mindset"]
    PLAN = STRATEGY["content_plan"]
    PAGE = STRATEGY["page_setup"]

    print("\n--- PAGE SETUP ---")
    print(PAGE)

    print("\n--- MINDSET ---")
    for s in MINDSET:
        print(f"{s.title}: {s.content}")

    print("\n--- DAY 1 GENERATED CONTENT ---")
    print(generate_ai_content_gemini(PLAN[0], MINDSET))
# Out:
# Generated strategy bundle with mindset, plan, and themes.
#
# --- PAGE SETUP ---
# page_name='Sức Mạnh Của Sự Kết Nối' intro_story='Chia sẻ câu chuyện về những người đàn ông đã vượt qua khó khăn nhờ sự hỗ trợ từ bạn bè, gia đình hoặc cộng đồng. Nhấn mạnh tầm quan trọng của việc mở lòng và tìm kiếm sự giúp đỡ khi cần thiết.'
#
# --- MINDSET ---
# Tư duy chiến dịch: Chiến dịch 'Nam Tính Mới' tập trung vào việc thay đổi nhận thức về vai trò và cảm xúc của nam giới trong xã hội hiện đại. Chúng ta khuyến khích sự kết nối, sẻ chia và chấp nhận sự tổn thương như một phần của sức mạnh. Insight chủ đạo là 'Đàn ông không nên chịu đựng một mình', thúc đẩy nam giới chủ động tìm kiếm sự hỗ trợ và xây dựng những mối quan hệ ý nghĩa.
#
# --- DAY 1 GENERATED CONTENT ---
# ...

# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
from pydantic import BaseModel
import asyncio
from typing import Dict, Any, List
import os, json

load_dotenv()


class Plan(BaseModel):
    order: Optional[int] = None          # STT - Post order
    title: str                            # Tiêu đề - Post title
    goal: Optional[str] = None            # Mục tiêu - Purpose or Objective
    content_idea: Optional[str] = None    # Gợi ý nội dung - Content suggestion
    format: Optional[str] = None          # Định dạng - Format type (storytelling, listicle, etc.)

class Theme(BaseModel):
    title: str
    story: str
    content_plan: List[Plan]

class ThemeGenerate(BaseModel):
    themes: List[Theme]

def generate_theme_title_and_story(campaign_title: str, insight: str, description: str, target_customer:str) -> List[tuple[str, str, List[str]]]:
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
    
    # Generate response using Gemini API (synchronous version)
    response = client.models.generate_content(
        model='gemini-2.0-flash',  # Updated to newer model version
        contents=f"Tạo 5 thương hiệu cho pages với các thông tin {insight} {target_customer}. Mỗi thương hiệu phải có title, story và content_plan khác nhau. Story là câu chuyện thương hiệu, content_plan là danh sách 5 tiêu đề hoặc hook cho các bài viết. Viết bằng tiếng việt",
        config=types.GenerateContentConfig(
            response_mime_type='application/json',
            response_schema=ThemeGenerate,
            system_instruction=types.Part.from_text(text=f"{description}, kết quả trả ra bằng tiếng việt"),
        ),
    )
    
    # Extract the response
    print("Generated 5 themes with content plans based on user prompt.")
    
    # Extract the response
    print("Generated 5 themes based on user prompt.")
    content = json.loads(response.text)
    
    # Validate and parse the response using Pydantic
    themes_data = ThemeGenerate(**content)
    
    # Convert list of themes to list of tuples using dot notation for Pydantic model attributes
    return [
        (
            theme.title,
            theme.story,
            [plan.model_dump() for plan in theme.content_plan]  # ⬅️ Here: get all plan titles cleanly
        )
        for theme in themes_data.themes
    ]

# %%
a = generate_theme_title_and_story("Nam Tính Mới", "Đàn ông không nên chịu đựng một mình", "Chiến dịch nâng cao nhận thức về cảm xúc và sự kết nối của nam giới hiện đại", "Nam giới 25–45 tuổi ở thành thị")
# Out:
# Generated 5 themes with content plans based on user prompt.
# Generated 5 themes based on user prompt.

# %%
b,c,d = a[0]

# %%
d
# Out:
# [{'order': None,
#   'title': "5 Dấu Hiệu Bạn Đang 'Gồng' Quá Sức và Cách Giải Quyết",
#   'goal': None,
#   'content_idea': None,
#   'format': None},
#  {'order': None,
#   'title': 'Sức Mạnh Của Sự Yếu Đuối: Vì Sao Thể Hiện Cảm Xúc Không Phải Là Dấu Hiệu Của Sự Thất Bại',
#   'goal': None,
#   'content_idea': None,
#   'format': None},
#  {'order': None,
#   'title': "Tìm Kiếm 'Bộ Lạc' Của Bạn: Xây Dựng Mạng Lưới Hỗ Trợ Cho Nam Giới Hiện Đại",
#   'goal': None,
#   'content_idea': None,
#   'format': None},
#  {'order': None,
#   'title': 'Podcast: Chuyện Của Những Người Đàn Ông: Chia Sẻ Về Những Khó Khăn Ít Ai Nói',
#   'goal': None,
#   'content_idea': None,
#   'format': None},
#  {'order': None,
#   'title': '10 Hoạt Động Giúp Bạn Giải Tỏa Căng Thẳng và Kết Nối Với Bản Thân',
#   'goal': None,
#   'content_idea': None,
#   'format': None}]

# %%
generate_theme_title_and_story
# Out:
# <function __main__.generate_theme_title_and_story(campaign_title: str, insight: str, description: str, target_customer: str) -> List[tuple[str, str, List[str]]]>
